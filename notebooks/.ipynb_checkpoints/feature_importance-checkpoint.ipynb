# %% [markdown]
# # Obtaining Important Features

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/data.csv')
data.drop('Unnamed: 32', axis=1, inplace = True)
data.drop('id',axis=1,inplace=True)
data.head(3)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38           122.8     1001.0
# 1         M        20.57         17.77           132.9     1326.0
# 2         M        19.69         21.25           130.0     1203.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
# 1         0.1812  ...         24.99          23.41            158.8
# 2         0.2069  ...         23.57          25.53            152.5
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
#
# [3 rows x 31 columns]

# %%
data['diagnosis'] = data.diagnosis.map({'M':1,'B':0})
X = data.iloc[:,1:]
y = data.iloc[:,0]

# %%
X.head(2)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
#
# [2 rows x 30 columns]

# %%
y.head(2)
# Out:
# 0    1
# 1    1
# Name: diagnosis, dtype: int64

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_)
# Out:
# [0.05699743 0.02004328 0.07620226 0.04880506 0.01086627 0.02299308
#  0.04213729 0.0900972  0.00736727 0.0061036  0.02103325 0.00543246
#  0.02423255 0.03513163 0.0065735  0.00746013 0.00603289 0.00991685
#  0.00503229 0.00690484 0.07863972 0.0225844  0.09628717 0.04903205
#  0.0225979  0.04687475 0.04181986 0.11264391 0.01068616 0.00947095]

# %% [markdown]
# plot graph of feature importances for better visualization

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.title('Top 15 features')
plt.show()

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)

feat_importances.nlargest(30).plot(kind='barh', figsize=(15,11))
plt.title('All feature Importance')
plt.show()
